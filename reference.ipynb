# %%
2/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Integer(2)/Integer(0)
#
# File ~/sage/src/sage/rings/integer.pyx:2040, in sage.rings.integer.Integer.__truediv__()
#    2038 if type(left) is type(right):
#    2039     if mpz_sgn((<Integer>right).value) == 0:
# -> 2040         raise ZeroDivisionError("rational division by zero")
#    2041     x = <Rational> Rational.__new__(Rational)
#    2042     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %% [markdown]
# $\Diamond$

# %% [markdown]
# **Math**

# %% [markdown]
# $\bullet$

# %% [markdown]
# $\frac{\frac{\sin a}{\cos a} + \frac{\sin b}{\cos b}}{1 - \frac{\sin a \sin b}{\cos a \cos b}}$

# %% [markdown]
# $\frac{5 - \frac{1}{x}}{4}$

# %% [markdown]
# $\hbar$

# %%
$\bigstar$**Author: Anonymous**

**Mathematical Physics**

$\Diamond$ **Useful Formulae:**  
$\bullet$ Constants:
$\hbar$*c $\simeq$197.3 MeV fm, 
$\frac{e^2}{\hbar c}$ $\simeq$ $\frac{1}{137}$, $m_e c^2$ $\simeq$ 0.511 MeV, $m_p c^2$ $\simeq$ 9.38 MeV. 
$\bullet$  Relativity: p = mv$\gamma$, E = $\gamma m$ $c^2$, $E^2$ = $p^2*c^2$ + $m^2*c^4$, $\gamma$ = $\frac{1}{\sqrt1 - \beta^2}$, $\beta$ = $\frac{v}{c}$.  
$\bullet$ de Broglie: $\lambda$ = $\frac{h}{p}$,  Compton: $\lambda_C$ = $\frac{h}{mc}$, $\hat{p}$ = $\frac{h}{i}$ $\frac{\partial}{\partial{x}}$, $\hat{x}_i, \hat{p}_j$ = $i \hbar$,
$\hat{p}$ = $\frac{\hbar}{i}$ $\nabla$, $\hat{x_i},\hat{p_j}$ = $i\hbar \delta_{ij}$,
$\hat{p},(f)\hat{x}$ = $\frac{\hbar}{i}$ $\frac{\partial{f}} {\partial{x_i}}$.  
$\bullet$ Schr$\ddot{o}$dinger equation: i $\hbar$ $\frac{\partial \psi}{\partial(t)}$ {x,t} = - $\frac{i h^2}{2 m}$ $\nabla^2$ + V (x,t) $\psi (x,t)$,  
$\frac{\partial}{\partial(t)}$ $\rho (x,t)$ + $\nabla$ * J (x,t)  = 0, $\rho$ (x,t) = | $\Psi (x,t) |^2$, $\mathbf J $ (x,t) = $\frac{\hbar} {m}$ Im $\psi^*$ $\nabla \psi$.  
$\bullet$ Fourier transforms: $\psi x$ = $\frac{1}{\sqrt2 \pi}$ $\int{dk}$ $\phi$ k $e^{ikx}$, $\Phi k$ = $\frac{1}{\sqrt2\pi}$ $\int{dx}$ $\Psi$ x $e^-{ikx}$, $\int${dx}| $\Psi (x) |^2$ = $\int {dk}$ | $\Phi k |^2$.  
$\frac{1}{2\pi}$ $\int_{-\infty}^{\infty} e^{ikx}{dx}$ = $\partial(k)$, $\frac{1}{(2\pi)^3}$ $\int(e)^{ik*x}(d)^3{x}$ = $\partial^{(3)}(k)$.  
$\int_{-\infty}^{\infty} dx \exp(-{ax}^2 + bx)$ = $\frac{\sqrt\pi}{\sqrt a}$ $\exp (\frac{b^2}{4a}$), when $\Re$(a) > 0.  
$\bullet$ expectation value: $\langle\hat{Q} \rangle$ $\equiv$ $\langle\psi, \hat{Q}\psi \rangle$, $i\hbar \frac{d}{dt}$ = $\langle[\hat{Q},{H}]\rangle$, $\hat{Q}$ time idependent.  
$\bullet$ uncertainty: $\vartriangle{A} \equiv \parallel(\hat{A} - \langle \hat{A} \rangle \mathbb{1}) \psi \parallel$,   
$\vartriangle{A}^2$ = $\langle \hat{A}^2 \rangle - \langle \hat{A} \rangle^2 \geq$ 0.  
$\vartriangle{A} \vartriangle{B}$ $\geq$ | $\langle \psi$ $\mid$ $\frac{1}{2i}$ $\hat{A},\hat{B}$ $\mid$ $\psi$ $\rangle$ |,  
$\bullet$ saturarion: $\hat{B} - \langle \hat{B} \rangle \mathbb1 | \psi \rangle$ = i $\lambda \hat{A} - \langle \hat{A} \mathbb1 | \psi \rangle$, $\lambda \in \Re$.  
$\vartriangle{x} \vartriangle{p} \geq \frac{\hbar}{2}$. For $\psi$ ~ $\exp(- \frac{1}{4} \frac{x^2}{\vartriangle^2})$,  
$\vartriangle{x} = \vartriangle$ and $\vartriangle{p} = \frac{\hbar}{2 \vartriangle}$.  
$\vartriangle{H} \vartriangle{t} \geq \frac{\hbar}{2}$, $\vartriangle{t}$ $\equiv$ $\frac{\vartriangle Q } {(|d \langle Q \rangle / {dt} |}$.  
$\bullet$ stationary state: $\psi{x,t} - \psi(x)e^{\frac{-iEt}{\hbar}}$, $- \frac{\hbar^2}{2m} \nabla^2 \psi(x) = E \psi(x)$.  
$\bullet$ variational principle: $E_{gs} \leq \langle \psi, \hat{H} \psi \rangle$, for all normalized $\psi$.  
$\bullet$ Hellmann-Feynmann: $\hat{H}(\lambda)$ = $E_n(\lambda) \psi_n(\lambda)$ $\longrightarrow$ $\frac{dE_n(\lambda)} {d \lambda}$ = $\langle \psi_n(\lambda)$, $\frac{d \hat{H}(\lambda)}{d \lambda}$ $\psi_n(\lambda) \rangle$.  
$\bullet$ virial theorem: one dimension: $\langle \frac{\hat{p}^2}{2m} \rangle $ = $\frac{1}{2} \langle \hat{x} \frac{dV}{dx} \rangle$,  
$\bullet$ central potential: $\langle \frac{\hat{p}^2}{2m} \rangle$ = $\frac{1}{2}$ $\langle{r}$ $\frac{\partial{V}}{\partial{r}} \rangle $.  
$\bullet$ commutator identities:  
[A,BC] = [A,B]C + B[A,C],  
$e^A Be^{-A}$ = $e^{ad_A}B $ = B + [A,B] + $\frac{1}{2} A,[A,B]] + \frac{1}{3} [A,[A,[A,B]]] +...$,  
$e^A Be^{-A}$ = B + [A,B], if  [A,[A,B]] = 0,  
$[B,e^A]$ = [$B,A]e^A$, if [ [A,[A,B]] = 0,  
$e^{A + B}$ = $e^A e^B e^{-\frac{1}{2}|A,B|}$ = $e^B e^A e^{\frac{1}{2}|A,B|}$ if [[A,B],A] = [[A,B],B] = 0.  
$\bullet$ matrix exponential: $e^{i M \theta}$ = $\mathbb 1 \cos \theta + i M\sin \theta$,  
$\bullet$ index manipulation: $ a \cdot b$ = $a_i b_i$, $\delta_{ij}B_j$, $\delta_{ij}$ = 3, $(a \times b)_i$ = $\epsilon_{ijk}$ $a_j$ $b_k$, $\epsilon 123 = 1$.  
$\epsilon_{ijk} \epsilon_{ipq}$ = $\delta_{jp} \delta_{qk} - \delta_{jp} \delta_{kp}$,  
$\epsilon_{ijk} \epsilon_{ijq}$ = $2 \delta_{kq}$.  
$\bullet$ linear algebra: matrix representation in the basis $(v_{1,...,}v_n)$: $Tv_i$ = $\sum_k $ $T_{kj}$ $v_k$.  
$\bullet$ basis change: $u_k$ = $\sum_j A_{jk}v_j$, T({u}) = $A^{-1} T ({v}) A$.  
$\bullet$ inner product: $\langle{v,v} \rangle$ $\geq$ 0, for all v, $\langle{v,v} \rangle$ = 0 if and only if v = 0, $\langle{u,v} \rangle$ = $\langle{vu} \rangle^*$.  
$\bullet$ Schwarz inequality: |(u,v)| $\leq$ $\parallel u \parallel$ $\parallel{v} \parallel$.  
$\bullet$ Complex vector space: $\langle v,Tv \rangle$ = 0, $\forall$ v $\in$ V $\longrightarrow$ T = 0.  
$\bullet$ adjoint: $\langle{u,Tv} \rangle$ = $\langle T^\dagger{u,v} \rangle$ , $(T^\dagger)^\dagger$ = T, $\langle(ST)^\dagger$ = $T^\dagger S^\dagger$.  
$\bullet$ Hermitian operator T: $T^\dagger$ = T .  
$\bullet$ unitary operator U: $U^\dagger U$ = $UU^\dagger$ = $\mathbb1$.  
$\bullet$ orthogonal projector: $P_u$: V $\longrightarrow$ U,  
${P_uP_u}$ = $P_u$,  
$P_u^\dagger$ = $P_u$,  
V = range$P_u \oplus$ null$P_u$.  
$\bullet$ bra-kets: $\langle{u|v} \rangle$ $\equiv$ $\langle{u,v} \rangle$, |Tv$\rangle$ $\equiv$ T|v$\rangle$, $\langle Tv$ = $\langle v|T^\dagger$, $\langle u|T^\dagger v$ = $\langle Tu|v \rangle$.  
|$\alpha_1 v_1$ + $\alpha_2 v_2 \rangle$ = $\alpha_1|v_1 \rangle$ + $\alpha_2|v_2 \rangle$,   
$\langle \alpha_1 v_1$ + $\alpha_2 v_2|$ = $\alpha_1^* \langle v_1|$ + $\alpha_2^* \langle v_2|$.  
T = |u$\rangle$ $\langle w$| $\longrightarrow$ $T^\dagger$ = |w$\rangle$ $\langle$ u|,  
**tr**T  = $\langle w|u \rangle$.  
$\bullet$ orthonormal basis $|i\rangle$: $\langle i|j \rangle$ = $\delta_{ij}$, $\mathbb1$  = $\sum_i|i \rangle \langle i |$.  
$T_{ij}$ = $\langle i|T|j \rangle$ $\longleftrightarrow$ T = $\sum_{i,j} T_{ij}$ |i$\rangle \langle$ j|, $\langle | T^\dagger |j \rangle^*$, $(T^\dagger)_{ij}$ = $(T_{ji})^*$.  
$[M,M^\dagger]$ = 0 $\longleftrightarrow$ M is unitarily diagonizable.  
$\bullet$ spectral theorem: $T^\dagger$ = T $\longrightarrow$ T = $\sum_k P_k$, $P_k^\dagger$ = $P_k$, $P_k P_l$ = $\delta_{kl}P_l$, $\sum_k P_k$ = 1.  
$\bullet$ Schr$\ddot{o}$dinger picture: |$\psi,t \rangle$ = $U(t,t_0) | \psi,t_0 \rangle$, $\hat{H}(t)$ = $i \hbar \frac{\partial l \lambda(t, t_0)}{\partial t}$,  
U(t,0) = $\exp(\frac{-i \hbar t}{\hbar})$, for $\hat{H}$ time independent.  
$\bullet$ Heisenberg picture: $\hat{A}_H(t)$ $\equiv$ $U^\dagger(t,0) \hat{A}_S U(t,0)$, $i \hbar \frac{d \hat{A}_H(t)}{dt}$ = $[\hat{A}(t)$, $\hat{H}_H(t)]$ + $i \hbar$ $\frac{\partial \hat{A}_H(t)}{dt}$.  
$\bullet$ harmonic oscillator: $\hat{H}$ = $\frac{1}{2m} \hat{p}^2$ + $\frac{1}{2}m \omega^2 \hat{x}^2$ = $i \hbar \omega(\hat{N}$ +$\frac{1}{2})$, $\hat{N}$ = $\hat{a}^\dagger \hat{a}$,  
$\hat{a}$ = $\frac{1}{\sqrt{2}L_0}$ $(\hat{x}$ + $\frac{i \hat{p}}{m \omega})$, $\hat{a}^\dagger$ = $\frac{1}{\sqrt{2}L_0}(\hat{x} - \frac{i \hat{p}}{m \omega})$, $L^2_0$ = $\frac{\hbar}{2 \omega}$,  
$\hat{x}$ = $\frac{L_0}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$, $\hat{p}$ = $\frac{i}{\sqrt{2}} \frac{\hbar}{L_0}(\hat{a}^\dagger - \hat{a})$,  
$|\hat{a}, \hat{a}^\dagger|$ = 1, $[\hat{N}, \hat{a}^\dagger|$ = $\hat{a}^\dagger$,  
$\hat{a} \varphi_0$ = 0, $\varphi_0(x)$ = $N_0 \exp(- \frac{1}{2} \frac{x^2}{L^2_0})$, $N^2_0$ = $\frac{1}{\sqrt{\pi}L_0}$,  
$\varphi_n$ = $\frac{1}{\sqrt{n!}} (a^\dagger)^n \varphi0 $, $\hat{N}\varphi_n$ = $n\varphi_n$, $\langle \varphi{m}, \varphi{n} \rangle$ = $\delta_{mn}$,  
$\hat{a}^\dagger \varphi_n$ = $\sqrt{n + 1} \varphi_n + 1$, $\hat{a} \varphi_n$ = $\sqrt{n} \varphi_{n - 1}$,  
$\hat{x}_H(t)$ = $\hat{x} \cos \omega{t} + \frac{\hat{p}}{m \omega} \sin{\omega{t}}$,  
$\hat{p}_H(t)$ = $\hat{p} \cos \omega{t} - m \omega \hat{x} \sin \omega{t}$.  
$\bullet$ coherent states: $|\alpha \rangle$ $\equiv$ $e^{\alpha{a}^\dagger - \alpha^*{a}}|0 \rangle$, $\alpha$ = $\frac{\langle \hat{x} \rangle} {\sqrt2{L_0}}$ + $i \frac{\langle \hat{p} \rangle L_0} {\sqrt2 \hbar}$ $\in$ $\mathbb{c}$.  
$\hat{a}| \alpha \rangle$ = $\alpha| \alpha \rangle$, |$\alpha \rangle$ = $e^{-{\frac{1}{2}} | \alpha|^2} e^\alpha a^\dagger |0 \rangle$, $| \alpha, t \rangle$ = $e^{-1 \omega t/2}|e^{-i \omega t} \alpha \rangle$.  
$\bullet$ orbital angular momentum: $\hat{L}_x$ = $\hat{y} \hat{p}_z - \hat{z} \hat{p}_y$, $\hat{L}_y$ = $\hat{z} \hat{p}_x - \hat{x} \hat{p}_z$, $\hat{L}_z$ = $\hat{x} \hat{p}_y - \hat{y} \hat{p}_x$,  
$[\hat{L}_x, \hat{L}_y]$ = $i \hbar \hat{L}_z$, $[\hat{L}_y, \hat{L}_z]$ = $i \hbar \hat{L}_x$, $[\hat{L}_z, \hat{L}_x]$ = $i \hbar \hat{L}_y$,  
$\hat{L}^2$ $\equiv$ $\hat{L}_x \hat{L}_x + \hat{L}_y \hat{L}_y + \hat{L}_z \hat{L}_z$, $[\hat{L}^2$, $\hat{L}_i]$ = 0.  
$\nabla^2$ = $\frac{\mathbf 1} {r}$ $\frac{\partial^2}{\partial \mathbf r^2}$ $\mathbf r$ - $\frac{\mathbf 1} {\mathbf r^2}$ $\frac{\hat L^2} {\hbar^2}$,  
$\hat{L}^2$ = $- \hbar^2$ $\frac{\partial^2}{\partial \theta^2}$ + $\cot$ $\theta$ $\frac{\partial}{\partial \theta}$ + $\frac{1}{\sin^2 \theta}$ $\frac{\partial^2}{\partial \phi^2}$,  
$\hat{L}_z$ = $\frac{\hbar}{\mathbb i}$ $\frac{\partial}{\partial \theta}$, $\hat{L}_\pm$ = $\hbar e^\pm i$ $\phi$ $\pm\frac{\partial}{\partial \theta}$ + i $\cot \theta$ $\frac{\partial}{\partial \theta}$.  
$Y_{\mathcal l m}$ $\theta, \phi$ = $\langle \theta \phi |  {\mathcal l m} \rangle$ = $Y_\mathcal {lm}$ $\Omega$ $\equiv$ $\mathcal N_{\mathcal l m}$ $P^m_\mathcal l$ $\cos$ $\theta$ $e^{i m \theta}$.

# %% [markdown]
# Professor Zweibach, while dicussing the properties of QM, asked the audience why they were laughing at humans' attempt to quantize gravity, as he also laughed. Life is laughter, while not keeping stuff simpler! Any typing errors is my prerogative. No space for boredom!

# %% [markdown]
# Abstraction is forever a task for the human mind.
#
#                              REFERENCES:
# 1. Masterinng Quantum Mechanics - Barton Zweibach
# 2. Quantum Mechanics - Leonard I. Schiff
# 3. Field Theory, Quantum Gravity and Strings(I and II) - H.J. de Vega and N. Sanchez
# 4. Atomic Structure and Spectral Lines - Arnold Sommerfeld
# 5. Wave Mechanics - Arnold Sommerfeld
# 6. Quantum Field Theory(Lectures of Sidney Coleman
# 7. Notes from Sidney Coleman's Physics 253a
# 8. Nature of Space and Time - Stephen Hawking and Roger Penrose
# 9. Quantum Mechanics - David Tong
# 10. Quantum Information and Computation - John Preskill
# 11. Superstring Theory - Micheal B. Green, John H. Schwarz, Edward Witten
# 12. Thomas Calculus - George B. Thomas
# 13. Lectures on Quantum Mechanics - Steven Weinberg
# 14. Mathematical Foundations of Quantum Mechanics - John Von Neumann
# 15. A course on Modern Analysis(5th Edition) - E.T.Whittaker and G.N.Watson
# 16. Quantum Computer Science N.David Mermer
# 17. The Python 3 Standard Library by Example - Doug Hellmann
# 18. The Annotated Turing - Charles Petzold
# 19. Lectures on Quantum Theory - Frederic Schuller
# 20. Essential Calculus Skills practice Workbook with full solutions - Chris McMullen
# 21. Speakable and Unspeakable in Quantum Mechanics - J.S.Bell
# 22. Introduction to Tensor Analysis and the Calculus of Moving Surfaces - Pavel Grinfeld
# 23. Quantum Mechanics(vol I and II) - Albert Messiah
# 24. Lecture notes for Linear Algebra - Terrence Tao
# 25. Black Holes - Brian Cox and Jeff Forshaw
# 26. Introduction to algorithms Thomas H. Cormen, Charles E. Leiserson, Ronal L. Rivest and Clifford Stein
# 27. Algebraic Number Theory, A Computational Approach - William Stein
# 28. Feynman lectures on physics(volume I,II and III)
# 29. A Guide to Feynman Diagrams in the Many-Body Problem - Richard Mattuck
# 30. Handbook of Physics - B.M.Yavorsky
# 31. Introduction to the theory of quantised fields - N.N. Bogoliubov
# 32. Fundamentals of Physics - David Halliday, Robert Resnick and Jearl Walker
# 33. Ohanian Physics(vol I and II)_second edition - Hans C. Ohanian
# 34. Applied Partial Differential Equations, with Fourier series and Boundary Value Problems - Richard Haberman
# 35. Introduction to Calculus and Analysis(Volume I and II) - Richard Courant
# 36. S-Matrix Theory of Strong Interactions - Geoffrey F. Chew
# 37. Engeneering Physics - Shatendra Sharma and Jyotsna Sharma
# 38. Introduction to Linear Algebra(Fifth edition) - Gilbert Strang
# 39. Calculus(Volume I, II and III) - Edwin Herman and Gilbert Strang
# 40. Advanced Quantum Mechanics - Freeman Dyson
# 41. The Mathematical Principles of Natural Philosophy(translated by Motte) - Isaac Newton
# 42. Lost in Math - Sabine Hossenfelder
# 43. Differential and integral calculus(Volume I and II) - N. Piskunov
# 44. Mathematical Methods in the Physical Sciences - Mary L. Boas
# 45. Applied Partial differentials_with Fourier Series and bondary value problems - Richard Haberman
# 46. Relativivitic quantum mechanics and relativistic quantum fields - James D. Bjorken and Sidney D. Drell
# 47. A course of modern analysis - E.T.Whittaker and G.N.Watson
# 48. CRC Standard Mathematical Tables and Formulae - Daniel Zwillinger
# 49. Introductory Mathematics for Engineers - A.D.Myskis
# 50. Methods of modern physics(volume I II III IV - Michael Reed and Barry Simon
# 51. Principles of Quantum Mechanics(2nd Edition) - R. Shankar
# 52. Molecular Quantum Mechanics(4th Edition) - Peter Atkins and Ronald Friedman
# 53. Right the Firt Time - Lee W. Ritchey
# 54. Introduction to Analysis of the infinite - Leonard Euler
# 55. Foundations of differeential calculus(translated by John D.Blanton) - Leonard Euler
# 56. Complete Mathematics notes for high schools
# 57. Linear Algebra Done Right - Sheldon Axler
# 58. Symmetry - Istvan Hargittai
# 59. Pure Mathematics Book 1(4th Edition) J.K.Backhouse, S.P.T.Houldsworth, and P.J.F.Horril
# 60. Quantum Mechanics, Determinism, Causility, and particles
# 61. Singularity theory and gravitation lensing - Arlie O. Peters, Harold Levine and Joachim Wambsganss
# 62. Orthogonal Functions(trnslated by Ainsley H. Diamond
# 63. Algorthms and Discreet Applied Mathematics
# 64. Gravitational N-Body Simulatioms_Tools and Algorithms - Sverre J. Aarseth
# 65. Mathematical computation with SageMath - Paul Zimmermann
# 66. Classical and Quantumn Computation - A.Yu Kitaev
# 67. Discrete Mathematics and its Application(8th Edition) - Kenneth H. Rosen
# 68. Masters of Theory - Andrew Warwick
# 69. Graduate texts in Mathematics - Serge Lang
# 70.The Mathematical Theory of Blackholes - S. Chandrasekhar
# 71. Modern Quantum Mechanics - J.J.Sakurai
# 72. History of functional analysis - Jean Dieudonne
# 73. Planck 201 results V. CMB Power Spectra and likelihoods
# 74. Einsteins' gravity in a nutshell - A. Zee
# 75. Aspects of Symmetry Sidney Coleman
# 76. Quantum Gravity Partition Functions In Three Dimensions - Alexander Maloney and Edward Witten
# 77. Essential Calculus-based Physics study guide workbook - Chris McMullen
# 78. A Course in computational algebraic number theory - Cohen H.
# 79. Theories of Gravity - Robert M. Wald and Andreas Zoupas
# 80. A first course in String Theory - Barton Zweibach
# 81. Relativity_The Special and General Theory - Albert Einstein
# 82. Fundamentals of Physics - R. Shankar
# 83. Calculus(10th Edition) - Anton Bivens Davis
# 84. Differential Equations for Engineers - Jeffrey R. Chasnov
# 85. A First Course in Linear Algebra - Robert A. Beezer
# 86. Can Quantum-Mechanical Description of Physical Reality be considered Complete? - A.Einstein, B.Podolsky and N.Rosen
# 87. An introductory course on Sage - Sasskia Roos and Michael Jung
# 88. NIST Handbook 0f Mathematical Functions - Olver, Lozier, Bisvert and Clark
# 89. Physics_For Scientists and Engineers(second Edition)_A Strategic Approach - Randall D. Knight
# 90. The Calculus Lifesaver - Adrian Banner
# 91. Algorithmic Thinking(2nd Edition) - Daniel Zingaro
# 92. Algorithms for programmers_ideas and source code - Jorg Arndt
# 93. Principles of digital communication and coding - Andrew Viterbi and Jim K. Omura
# 94. Quanntum Mecchanics(Volume I and II) - Claude Cohen-Tannoudji, Bernard Diu and Franck Laloe
# 95. Machine vision_Lecture notes - Berthold Horn, Ryan Sander  and Tadayuki Yoshitake
# 96. Introduction to Quantum Mechanics - David J. Griffiths and Darrell F. Schroeter
# 97. Hyperbolic Differential Equations - Jean Leray
# 98. Theory of Orbits_The restricted problem of three bodies - Victor Szebehely
# 99. Quantum Theory, Groups and Representations_An introduction - Peter Woit
# 100. Numbers and Functions - R.P.Burn

# %% [markdown]
# #
